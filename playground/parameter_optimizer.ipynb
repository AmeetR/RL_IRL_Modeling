# %%
from simanneal import Annealer
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import scipy.io as sio
from typing import Dict, Tuple
import pickle as pkl
import h5py

# %%
class data(list): 
    """
    This is a basic class to hold our data and check for equality 
    of a list of actions generated by the agent and generated by the 
    mouse. Later, there will more complex ways of scoring in this class
    """
    actions: np.matrix = None
    all_data = np.matrix = None
    def __init__(self, input_data: list): 
        if agent:
            self.actions = np.matrix(input_data)
        else:
            print("Please instantiate a mouse class instead of a data class")
        
        
    def __eq__(self, other): 
        for index in range(len(self.actions)):
            if self.actions[index] != other.actions[index]:
                return False
        return True
        

    def __ne__(self, other):
        return not self.__eq__(other)
    
    
    def score(self, d2):
        assert len(self.actions) == len(data.d2.actions)
        score = 0
        for i in range(len(self.actions)): 
            if self.actions[i] == d2.actions[i]: 
                score += 1
        return score/len(self.actions)
    
    def loss(self):
        """
        The default loss will be cross entropy loss: 
        
        We want to sum over the actions and calculate the -log likelihood
        of the given data (what we are optimizing for) under the generated model. 
        We possibly want to take the average over all of the actions. We can use q
        values as proxies for probabilites (that's effectively what they are)
        """
        pass
    
class mouse(data): 
    def __init__(self, matlab_url):
        #mat = sio.loadmat('../data/pilot_data_2odor_8020prob.mat')
        f = h5py.File('../data/pilot_data_2odor_8020prob.mat','r') 
        self.result = f.get('group_setsize2_result')
        #self.rewards = mat['group_setsize2_reward'][0][0][0]
        #self.ports = mat['group_setsize2_portside'][0][0][0]
    
    


class parameter_optimizer(): 
    """
    This class will run gradient descent
    in order to find the correct parameters for a single mouse
    """
    weight: np.matrix = None
    def __init__(self, data, rl_agent):
        pass
    
    def run_gradient_descent(self, alpha): 
        pass

# %%
#mat_contents = sio.loadmat('../data/pilot_data_2odor_8020prob.mat')
#result = mat_contents['group_setsize2_result'][0][0][0]
#rewards = mat_contents['group_setsize2_reward'][0][0][0]
#ports = mat_contents['group_setsize2_portside'][0][0][0]

m = mouse('../data/pilot_data_2odor_8020prob.mat')
m.result
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-c6956bf87c61> in <module>
#       4 #ports = mat_contents['group_setsize2_portside'][0][0][0]
#       5
# ----> 6 m = mouse('../data/pilot_data_2odor_8020prob.mat')
#       7 m.result
#
# <ipython-input-7-bf13b80fe73d> in __init__(self, matlab_url)
#      47     def __init__(self, matlab_url):
#      48         #mat = sio.loadmat('../data/pilot_data_2odor_8020prob.mat')
# ---> 49         f = h5py.File('../data/pilot_data_2odor_8020prob.mat','r')
#      50         self.result = f.get('group_setsize2_result')
#      51         #self.rewards = mat['group_setsize2_reward'][0][0][0]
#
# ~/.local/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# ~/.local/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     168         if swmr and swmr_support:
#     169             flags |= h5f.ACC_SWMR_READ
# --> 170         fid = h5f.open(name, flags, fapl=fapl)
#     171     elif mode == 'r+':
#     172         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %%
len(mat_contents['group_setsize2_reward'][0][0][0])
# Out:
# 1158

# %%
len(mat_contents['group_setsize2_portside'][0][0][0])
# Out:
# 1158

# %%
mat_contents

# %%
temp = np.array(["test", "test"])

# %% [markdown]
# temp

# %%
temp[0]
# Out:
# 'test'

# %%
list(all_data)
# Out:
# [(1.2, 1, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (3.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 2),
#  (2.0, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 1, 1),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 2),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 2),
#  (2.0, 1, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 1, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (2.0, 1, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (2.0, 1, 2),
#  (2.0, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (1.2, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 2),
#  (1.2, 0, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 1),
#  (2.0, 1, 2),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (2.0, 1, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 1),
#  (1.2, 0, 1),
#  (2.0, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (2.0, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 0, 1),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (2.0, 0, 2),
#  (1.2, 1, 1),
#  (2.0, 1, 1),
#  (1.2, 0, 2),
#  (2.0, 0, 1),
#  (1.2, 1, 1),
#  (2.0, 0, 2),
#  (1.2, 1, 2),
#  (1.2, 1, 1),
#  (1.2, 1, 1),
#  ...]

# %%
np.matrix(["test", "test2", "test3"]) - np.matrix(["test", "test2", "test3"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-fab3fc12c4dd> in <module>
# ----> 1 np.matrix(["test", "test2", "test3"]) - np.matrix(["test", "test2", "test3"])
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U5') dtype('<U5') dtype('<U5')

# %%
np.matrix([1,2,3]) - np.matrix([1,5,3])
# Out:
# matrix([[ 0, -3,  0]])

# %%
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b5edb7b78a9a> in <module>
# ----> 1 f.close()
#
# NameError: name 'f' is not defined
