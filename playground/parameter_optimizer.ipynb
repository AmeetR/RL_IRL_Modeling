# %%
from simanneal import Annealer
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import scipy.io as sio
from typing import Dict, Tuple
import pickle as pkl

# %%
class data(list): 
    """
    This is a basic class to hold our data and check for equality 
    of a list of actions generated by the agent and generated by the 
    mouse. Later, there will more complex ways of scoring in this class
    """
    actions: np.array = None
    def __init__(self, input_data: list, agent = True): 
        if agent:
            self.actions = np.array(input_data)
        else:
            pass
        
        
    def __eq__(self, other): 
        pass
        
    def __ne__(self, other):
        return not self.__eq__(other)
    
    
    def score(self, d2: data):
        pass
    
    


class parameter_optimizer(Annealer): 
    """
    This class will run simulated annealing using the simanneal library
    in order to find the correct parameters for a single mouse
    """
    def __init__(self, ):
        print("yeet")
        
    def move(self):
        pass
    
    def energy(self):
        pass

# %%
mat_contents = sio.loadmat('../data/pilot_data_2odor_8020prob.mat')
mat_contents['group_setsize2_result'][0][0][0]
# Out:
# array([1.2, 2. , 1.2, ..., 1.2, 2. , 1.2])

# %%
len(mat_contents['group_setsize2_reward'][0][0][0])
# Out:
# 1158

# %%
len(mat_contents['group_setsize2_portside'][0][0][0])
# Out:
# 1158

# %%
mat_contents

# %%
temp = np.array(["test", "test"])

# %% [markdown]
# temp

# %%
temp[0]
# Out:
# 'test'
